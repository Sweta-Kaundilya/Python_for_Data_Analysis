# %% [markdown]
# # DataFrames III: Data Extraction

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset is a collection of all James Bond movies.

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# ## The set_index and reset_index Methods
# - The index serves as the collection of primary identifiers/labels/entrypoints for the rows.
# - The fastest way to extract a row is from a sorted index by position/label.
# - Pandas uses index labels/values when merging different objects together.
# - The `set_index` method sets an existing column as the index of the **DataFrame**.
# - The `reset_index` method sets the standard ascending numeric index as the index of the **DataFrame**.

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond = bond.set_index("Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index().head()
bond.reset_index(drop=False).head() #keeps the old index
bond.reset_index(drop=True).head() #drops the old index and gives the default index numbers
# Out:
#    Year         Actor       Director  Box Office  Budget  Bond Actor Salary
# 0  1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1  1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 2  1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 3  1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 4  1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
bond.set_index("Year").head() #the old index is lost absolutely and that's why we need reset index command
# Out:
#              Actor       Director  Box Office  Budget  Bond Actor Salary
# Year
# 1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
bond = bond.reset_index().set_index("Year")

# %%
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %% [markdown]
# ## Retrieve Rows by Index Position with iloc Accessor
# - The `iloc` accessor retrieves one or more rows by index position.
# - Provide a pair of square brackets after the accessor.
# - `iloc` accepts single values, lists, and slices.

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.iloc[5]
bond.iloc[[15,20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond.iloc[4:8]
bond.iloc[0:6]
bond.iloc[:6]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
# 5    You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN
# 5    59.9                4.4

# %%
bond.iloc[20:]
# Out:
#                        Film  Year           Actor            Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig     Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                  Skyfall  2012    Daniel Craig          Sam Mendes
# 25                  Spectre  2015    Daniel Craig          Sam Mendes
# 26           No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ## Retrieve Rows by Index Label with loc Accessor
# - The `loc` accessor retrieves one or more rows by index label.
# - Provide a pair of square brackets after the accessor.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.loc[["Octopussy", "Moonraker"]]
bond.loc[["Moonraker", "Octopussy"]]
bond.loc[["Moonraker", "Octopussy", "Casino Royale"]]
#bond.loc[["Moonraker", "Octopussy", "Casino Royale","Gold Bond"]] #even one wrong value will give an error
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Moonraker      1979   Roger Moore    Lewis Gilbert       535.0    91.5
# Octopussy      1983   Roger Moore        John Glen       373.8    53.9
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Moonraker                    NaN
# Octopussy                    7.8
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.loc["Diamonds Are Forever":"Moonraker"] #order of things matter here
# Out:
#                              Year         Actor       Director  Box Office  \
# Film
# Diamonds Are Forever         1971  Sean Connery   Guy Hamilton       442.5
# Live and Let Die             1973   Roger Moore   Guy Hamilton       460.3
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977   Roger Moore  Lewis Gilbert       533.0
# Moonraker                    1979   Roger Moore  Lewis Gilbert       535.0
#
#                              Budget  Bond Actor Salary
# Film
# Diamonds Are Forever           34.7                5.8
# Live and Let Die               30.8                NaN
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN
# Moonraker                      91.5                NaN

# %%
bond.loc["Moonraker":"Diamonds Are Forever"] #whichever value lies first in the index should be used first
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
bond.loc["GoldenEye":]
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# GoldenEye                1995  Pierce Brosnan     Martin Campbell       518.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori       465.4
# Casino Royale            2006    Daniel Craig     Martin Campbell       581.5
# Quantum of Solace        2008    Daniel Craig        Marc Forster       514.2
# Skyfall                  2012    Daniel Craig          Sam Mendes       943.5
# Spectre                  2015    Daniel Craig          Sam Mendes       726.7
# No Time to Die           2021    Daniel Craig  Cary Joji Fukunaga       774.2
#
#                          Budget  Bond Actor Salary
# Film
# GoldenEye                  76.9                5.1
# Tomorrow Never Dies       133.9               10.0
# The World Is Not Enough   158.3               13.5
# Die Another Day           154.2               17.9
# Casino Royale             145.3                3.3
# Quantum of Solace         181.4                8.1
# Skyfall                   170.2               14.5
# Spectre                   206.3               30.0
# No Time to Die            301.0               25.0

# %%
bond.loc[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
#bond.loc[:"Casino Royale"] #Casino Royale occurs twice and this command confuses pandas, so it gives an error
#bond.loc["Casino Royale":] #This gives the same error

# %% [markdown]
# ## Second Arguments to loc and iloc Accessors
# - The second value inside the square brackets targets the columns.
# - The `iloc` requires numeric positions for rows and columns.
# - The `loc` requires labels for rows and columns.

# %%
bond = pd.read_csv("jamesbond.csv",index_col = "Film")
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc["Diamonds Are Forever", "Director"]
# Out:
# 'Guy Hamilton'

# %%
bond.loc[["Octopussy","GoldenEye"],"Director"]
# Out:
# Film
# Octopussy          John Glen
# GoldenEye    Martin Campbell
# Name: Director, dtype: object

# %%
bond.loc[["Octopussy","GoldenEye"],"Director":"Budget"]
# Out:
#                   Director  Box Office  Budget
# Film
# Octopussy        John Glen       373.8    53.9
# GoldenEye  Martin Campbell       518.5    76.9

# %%
 bond.loc["Octopussy":"GoldenEye",["Actor","Bond Actor Salary","Year"]]
# Out:
#                                Actor  Bond Actor Salary  Year
# Film
# Octopussy                Roger Moore                7.8  1983
# A View to a Kill         Roger Moore                9.1  1985
# The Living Daylights  Timothy Dalton                5.2  1987
# Licence to Kill       Timothy Dalton                7.9  1989
# GoldenEye             Pierce Brosnan                5.1  1995

# %%
bond.iloc[0,2]
# Out:
# 'Terence Young'

# %%
bond.iloc[3,5]
# Out:
# 4.7

# %%
bond.iloc[[0,2],3]
# Out:
# Film
# Dr. No        448.8
# Goldfinger    820.4
# Name: Box Office, dtype: float64

# %%
bond.iloc[[0,2],[3,5]]
# Out:
#             Box Office  Bond Actor Salary
# Film
# Dr. No           448.8                0.6
# Goldfinger       820.4                3.2

# %%
bond.iloc[:7, :3]
# Out:
#                                  Year           Actor       Director
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt

# %% [markdown]
# ## Overwrite Value in a DataFrame
# - Use the `iloc` or `loc` accessor on the **DataFrame** to target a value, then provide the equal sign and a new value.

# %%
bond = pd.read_csv("jamesbond.csv", index_col= "Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond["Actor"].loc["Diamonds Are Forever"] = "Sir Sean Connery" #works but it also gives a warning
# Out:
# C:\Users\sweta\AppData\Local\Temp\ipykernel_6060\2176815844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bond["Actor"].loc["Diamonds Are Forever"] = "Sir Sean Connery"

# %%
bond.loc["Diamonds Are Forever","Actor"] = "Sir Sean Connery" #better way to excute the code without warning

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ##  Overwrite Multiple Values in a DataFrame
# - The `replace` method replaces all occurrences of a **Series** value with another value (think of it like "Find and Replace").
# - To overwrite multiple values in a **DataFrame**, remember to use an accessor on the **DataFrame** itself.
# - Accessors like `loc` and `iloc` can accept Boolean Series. Use them to target the values to overwrite.

# %%
bond = pd.read_csv("jamesbond.csv",index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond["Actor"] = bond["Actor"].replace("Sean Connery","Sir Sean Connery")

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
 bond[bond["Actor"] == "Sean Connery"].loc[:, "Actor"] = "Sir Sean Connery"
# Out:
# C:\Users\sweta\AppData\Local\Temp\ipykernel_6060\3444983663.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   bond[bond["Actor"] == "Sean Connery"].loc[:, "Actor"] = "Sir Sean Connery"

# %%
is_sean_connery = bond["Actor"] == "Sean Connery"
bond.loc[is_sean_connery,"Actor"] = "Sir Sean Connery"

# %%
bond.head()
# Out:
#                       Year             Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Roger Moore        John Glen       275.2
# Casino Royale         2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002    Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame
# - The `rename` method accepts a dictionary for either its `columns` or `index` parameters.
# - The dictionary keys represent the existing names and the values represent the new names.
# - We can replace all columns by overwriting the **DataFrame's** `columns` attribute.

# %%
bond = pd.read_csv("jamesbond.csv", index_col= "Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond = bond.rename(columns={"Year":"Year of Release", "Box Office":"Revenue"})
bond.head()
# Out:
#                       Year of Release           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
#
#                       Revenue  Budget  Bond Actor Salary
# Film
# A View to a Kill        275.2    54.5                9.1
# Casino Royale           581.5   145.3                3.3
# Casino Royale           315.0    85.0                NaN
# Diamonds Are Forever    442.5    34.7                5.8
# Die Another Day         465.4   154.2               17.9

# %%
swaps = {
    "Dr. No":"Dr No",
    "GoldenEye":"Golden Eye",
    "The World is Not Enough":"Best Bond Movie Ever"
}

bond = bond.rename(index=swaps)
bond.head()
# Out:
#                       Year of Release           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
#
#                       Revenue  Budget  Bond Actor Salary
# Film
# A View to a Kill        275.2    54.5                9.1
# Casino Royale           581.5   145.3                3.3
# Casino Royale           315.0    85.0                NaN
# Diamonds Are Forever    442.5    34.7                5.8
# Die Another Day         465.4   154.2               17.9

# %%
bond.columns
# Out:
# Index(['Year of Release', 'Actor', 'Director', 'Revenue', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
type(bond.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
bond.columns = ["Year", "Bond Guy", "Camera Dude", "Revenues", "Cost","Salary" ] #This will only work in case every column name has to be change

# %%
bond.columns[3] = "The Money" # Can not change the name of a single column using this, use the rename method for that
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 bond.columns[3] = "The Money"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame
# - The `drop` method deletes one or more rows/columns from a **DataFrame**.
# - Pass the `index` or `columns` parameters a list of the column names to remove.
# - The `pop` method removes and returns a single **Series** (it mutates the **DataFrame** in the process).
# - Python's `del` keyword also removes a single **Series**.

# %%
bond = pd.read_csv("jamesbond.csv",index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop(columns=["Box Office","Budget"])
bond.drop(index=["No Time to Die","Casino Royale"])

bond.drop(index=["No Time to Die","Casino Royale"],columns=["Box Office","Budget"])
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Bond Actor Salary
# Film
# A View to a Kill                               9.1
# Diamonds Are Forever                           5.8
# Die Another Day                               17.9
# Dr. No                                         0.6
# For Your Eyes Only                             NaN
# From Russia with Love                          1.6
# GoldenEye                                      5.1
# Goldfinger                                     3.2
# Licence to Kill                                7.9
# Live and Let Die                               NaN
# Moonraker                                      NaN
# Never Say Never Again                          NaN
# Octopussy                                      7.8
# On Her Majesty's Secret Service                0.6
# Quantum of Solace                              8.1
# Skyfall                                       14.5
# Spectre                                       30.0
# The Living Daylights                           5.2
# The Man with the Golden Gun                    NaN
# The Spy Who Loved Me                           NaN
# The World Is Not Enough                       13.5
# Thunderball                                    4.7
# Tomorrow Never Dies                           10.0
# You Only Live Twice                            4.4

# %%
bond.head() #drop is non mutational, all the columns are still the same
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
actor = bond.pop("Actor")
actor.head()
# Out:
# Film
# A View to a Kill           Roger Moore
# Casino Royale             Daniel Craig
# Casino Royale              David Niven
# Diamonds Are Forever      Sean Connery
# Die Another Day         Pierce Brosnan
# Name: Actor, dtype: object

# %%
bond.head() #pop method just deleted the Actor column
# Out:
#                       Year         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985        John Glen       275.2    54.5
# Casino Royale         2006  Martin Campbell       581.5   145.3
# Casino Royale         1967       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971     Guy Hamilton       442.5    34.7
# Die Another Day       2002     Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %%
del bond["Year"] # in pop we can store and preserve the dropped column while del doesn't give that option

# %%
bond.head() # after del the Year column is dropped from the main dataframe
# Out:
#                              Director  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill            John Glen       275.2    54.5                9.1
# Casino Royale         Martin Campbell       581.5   145.3                3.3
# Casino Royale              Ken Hughes       315.0    85.0                NaN
# Diamonds Are Forever     Guy Hamilton       442.5    34.7                5.8
# Die Another Day          Lee Tamahori       465.4   154.2               17.9

# %% [markdown]
# ## Create Random Sample with the sample Method
# - The `sample` method returns a specified one or more random rows from the **DataFrame**.
# - Customize the `axis` parameter to extract random columns.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sample()
bond.sample(n=5)
bond.sample(n=3,axis="rows")
# Out:
#                       Year           Actor      Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971    Sean Connery  Guy Hamilton       442.5    34.7
# A View to a Kill      1985     Roger Moore     John Glen       275.2    54.5
# The Living Daylights  1987  Timothy Dalton     John Glen       313.5    68.8
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# A View to a Kill                    9.1
# The Living Daylights                5.2

# %%
bond.sample(n=2,axis="columns")
# Out:
#                                  Box Office  Budget
# Film
# A View to a Kill                      275.2    54.5
# Casino Royale                         581.5   145.3
# Casino Royale                         315.0    85.0
# Diamonds Are Forever                  442.5    34.7
# Die Another Day                       465.4   154.2
# Dr. No                                448.8     7.0
# For Your Eyes Only                    449.4    60.2
# From Russia with Love                 543.8    12.6
# GoldenEye                             518.5    76.9
# Goldfinger                            820.4    18.6
# Licence to Kill                       250.9    56.7
# Live and Let Die                      460.3    30.8
# Moonraker                             535.0    91.5
# Never Say Never Again                 380.0    86.0
# No Time to Die                        774.2   301.0
# Octopussy                             373.8    53.9
# On Her Majesty's Secret Service       291.5    37.3
# Quantum of Solace                     514.2   181.4
# Skyfall                               943.5   170.2
# Spectre                               726.7   206.3
# The Living Daylights                  313.5    68.8
# The Man with the Golden Gun           334.0    27.7
# The Spy Who Loved Me                  533.0    45.1
# The World Is Not Enough               439.5   158.3
# Thunderball                           848.1    41.9
# Tomorrow Never Dies                   463.2   133.9
# You Only Live Twice                   514.2    59.9

# %% [markdown]
# ## The nsmallest and nlargest Methods
# - The `nlargest` method returns a specified number of rows with the largest values from a given column.
# - The `nsmallest` method returns rows with the smallest values from a given column.
# - The `nlargest` and `nsmallest` methods are more efficient than sorting the entire **DataFrame**.

# %%
bond = pd.read_csv("jamesbond.csv",index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# Retrive the 4 films with the highest/largest box office gross
bond.sort_values("Box Office", ascending=False).head(4)
# Out:
#                 Year         Actor            Director  Box Office  Budget  \
# Film
# Skyfall         2012  Daniel Craig          Sam Mendes       943.5   170.2
# Thunderball     1965  Sean Connery       Terence Young       848.1    41.9
# Goldfinger      1964  Sean Connery        Guy Hamilton       820.4    18.6
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2   301.0
#
#                 Bond Actor Salary
# Film
# Skyfall                      14.5
# Thunderball                   4.7
# Goldfinger                    3.2
# No Time to Die               25.0

# %%
bond.nlargest(n=4,columns="Box Office")
# Out:
#                 Year         Actor            Director  Box Office  Budget  \
# Film
# Skyfall         2012  Daniel Craig          Sam Mendes       943.5   170.2
# Thunderball     1965  Sean Connery       Terence Young       848.1    41.9
# Goldfinger      1964  Sean Connery        Guy Hamilton       820.4    18.6
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2   301.0
#
#                 Bond Actor Salary
# Film
# Skyfall                      14.5
# Thunderball                   4.7
# Goldfinger                    3.2
# No Time to Die               25.0

# %%
bond["Box Office"].nlargest(4)
# Out:
# Film
# Skyfall           943.5
# Thunderball       848.1
# Goldfinger        820.4
# No Time to Die    774.2
# Name: Box Office, dtype: float64

# %%
bond.nsmallest(3, columns= "Bond Actor Salary")
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# From Russia with Love            1963    Sean Connery  Terence Young
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6

# %%
bond["Bond Actor Salary"].nsmallest(3)
# Out:
# Film
# Dr. No                             0.6
# On Her Majesty's Secret Service    0.6
# From Russia with Love              1.6
# Name: Bond Actor Salary, dtype: float64

# %%
#bond.nlargest(n=2, columns="Actor") # if you want to sort by alphabets then use sort_values and if you want to sort by numeric columns use nlargest & nsmallest

# %% [markdown]
# ## Filtering with the where Method
# - Similar to square brackets or `loc`, the `where` method filters the original `DataFrame` with a Boolean Series.
# - Pandas will populate rows that do **not** match the criteria with `NaN` values.
# - Leaving in the `NaN` values can be advantageous for certain merge and visualization operations.

# %%
bond = pd.read_csv("jamesbond.csv", index_col= "Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
actor_is_sean_connery = bond["Actor"] == "Sean Connery"
bond[actor_is_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.loc[actor_is_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.where(actor_is_sean_connery)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# Never Say Never Again            1983.0  Sean Connery  Irvin Kershner
# No Time to Die                      NaN           NaN             NaN
# Octopussy                           NaN           NaN             NaN
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Quantum of Solace                   NaN           NaN             NaN
# Skyfall                             NaN           NaN             NaN
# Spectre                             NaN           NaN             NaN
# The Living Daylights                NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# The World Is Not Enough             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Tomorrow Never Dies                 NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                 380.0    86.0                NaN
# No Time to Die                          NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# ## The apply Method with DataFrames
# - The `apply` method invokes a function on every column or every row in the **DataFrame**.
# - Pass the uninvoked function as the first argument to the `apply` method.
# - Pass the `axis` parameter an argument of `"columns"` to invoke the function on every row.
# - Pandas will pass in the row's values as a **Series** object. We can use accessors like `loc` and `iloc` to extract the column's values for that row.

# %%
bond = pd.read_csv("jamesbond.csv",index_col="Film").sort_index()
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond["Actor"].apply(len)
# Out:
# Film
# A View to a Kill                   11
# Casino Royale                      12
# Casino Royale                      11
# Diamonds Are Forever               12
# Die Another Day                    14
# Dr. No                             12
# For Your Eyes Only                 11
# From Russia with Love              12
# GoldenEye                          14
# Goldfinger                         12
# Licence to Kill                    14
# Live and Let Die                   11
# Moonraker                          11
# Never Say Never Again              12
# No Time to Die                     12
# Octopussy                          11
# On Her Majesty's Secret Service    14
# Quantum of Solace                  12
# Skyfall                            12
# Spectre                            12
# The Living Daylights               14
# The Man with the Golden Gun        11
# The Spy Who Loved Me               11
# The World Is Not Enough            14
# Thunderball                        12
# Tomorrow Never Dies                14
# You Only Live Twice                12
# Name: Actor, dtype: int64

# %%
bond.head(1)
# Out:
#                   Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
#MOVIE RANKING SYSTEM
#
#CONDITION      -> DESIGNATION
#80s movie      -> "Great 80's flick"
#Pierce Brosnan -> "The best Bond ever"
#Budget > 100   -> "Expensive movie,fun"
#Others         -> "No Comment"

def rank_movie(row):
    year = row.loc["Year"]
    actor = row.loc["Actor"]
    budget = row.loc["Budget"]

    if year >= 1980 and year < 1990:
        return "Great 80s flick!"

    if actor == "Pierce Brosnan":
        return "The best bond ever!"

    if budget > 100:
        return "Expensive movie,fun"

    return "No comment"

bond.apply(rank_movie,axis = "columns")
# Out:
# Film
# A View to a Kill                      Great 80s flick!
# Casino Royale                      Expensive movie,fun
# Casino Royale                               No comment
# Diamonds Are Forever                        No comment
# Die Another Day                    The best bond ever!
# Dr. No                                      No comment
# For Your Eyes Only                    Great 80s flick!
# From Russia with Love                       No comment
# GoldenEye                          The best bond ever!
# Goldfinger                                  No comment
# Licence to Kill                       Great 80s flick!
# Live and Let Die                            No comment
# Moonraker                                   No comment
# Never Say Never Again                 Great 80s flick!
# No Time to Die                     Expensive movie,fun
# Octopussy                             Great 80s flick!
# On Her Majesty's Secret Service             No comment
# Quantum of Solace                  Expensive movie,fun
# Skyfall                            Expensive movie,fun
# Spectre                            Expensive movie,fun
# The Living Daylights                  Great 80s flick!
# The Man with the Golden Gun                 No comment
# The Spy Who Loved Me                        No comment
# The World Is Not Enough            The best bond ever!
# Thunderball                                 No comment
# Tomorrow Never Dies                The best bond ever!
# You Only Live Twice                         No comment
# dtype: object
